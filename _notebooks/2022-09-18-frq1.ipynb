// %% [markdown]
// # Iteration Mini-Lab

// %%
import java.util.*;

public class Chickenegg {
    String[][] chicken = {
      {
        "     __//  ",
        "   /.__.\ ",
        "   \ \/ /  ",
        "'__/    \ ",
        " \-      )",
        "  \_____/ ",
        "____|_|____",
        "    " " ",
      },
      {
        "                   //	 ",
        " ww_          ___.///	 ",
        "o__ `._.-'''''    //	 ",
        "|/  \   ,     /   //	",
        "     \  ``,,,' _//	",
        "       `-.  \--'   .'`.	",
        "          \_/_/    `.,'	 ",
        "           \\\\		",
        "          ,,','`   	"
      },
      {
        "    __ ",
        "   W._`\._",
        "   |/ \   `-._._._.-//",
        "    _  \ `.__.'  _//",
        "   `v'\_`-.  \--'   _",
        "  .^.`..    \_/_/   <'\-_// ",
        " .' `.  '`   // \\   `-.-'",
        " '`_'`     -'` -'`    '' ",
        "  ' `"
      },
      {
        "   ()",
        "   ))    ((",
        "  //      \\\\",
        " | \\\\____// |",
        "\\~/ ~    ~\\/~~/",
        " (|    _/o  ~~",
        "  /  /     ,|",
        " (~~~)__.-\\ |",
        "  ``~~    | |",
        "   |      | |"
      }
    };
  
    String[] tiger = {
      "                         __,,,,_",
      "          _ __..-;''`--/'/ /.',-`-.",
      "     /'`\\ \\   |  \\ | \\| // // / -.,/_,'-,",
      "    /<7' ;  \\ \\  | ; ||/ /| | \\/    |`-/,/-.,_,/')",
      "   /  _.-, `,-\\,__|  _-| / \\ \\/|_/  |    '-/.;.\\'",
      "   `-`  f/ ;      / __/ \\__ `/ |__/ |",
      "        `-'      |  -| =|\\_  \\  |-' |",
      "              __/   /_..-' `  ),'  //",
      "          fL ((__.-'((___..-'' \\__.'"
  
    };
  
    public void printText () {
      for (int count = 4; count >= 1; count--) {
        System.out.println("Here comes " + count + " chicken\n");
        for (int i = 0; i<chicken[0].length; i++) {
          for (int j = 0; j<count; j++) {
            System.out.print(chicken[j][i] + "    ");
          }
          System.out.println();
        }
        System.out.println("Then the tiger arrives");
    
        for (int i = 0; i<tiger.length; i++) {
          System.out.println(tiger[i]);
        }
        System.out.println();
        System.out.println("Now there are " + (count-1) + " chicken\n");
      }
    }
  }

  Chickenegg myText = new Chickenegg();
myText.printText();
// Out:
// |           "   /.__.\ ",
// illegal escape character
//
// |           "   \ \/ /                ",
// illegal escape character
//
// |           "   \ \/ /                ",
// illegal escape character
//
// |           "'__/    \ ",
// illegal escape character
//
// |           " \-      )",
// illegal escape character
//
// |           "  \_____/ ",
// illegal escape character
